# %%
import numpy as np
import time
from scipy.stats import t

# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml('mnist_784', version=1, return_X_y=True)#, parser='auto')
X = X.values

X = X / 255. #normalization to [0,1]

y = X

print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000, 784)

# %%
from sklearn.model_selection import train_test_split


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=10000, random_state=123)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_temp, y_temp, test_size=5000, random_state=123)

del X_temp, y_temp, X, y

# %%
##########################
### t_prior_VAE
##########################
def sigmoid(z):
    return 1. / (1. + np.exp(-z))

def relu(z): #relu
    return np.maximum(0, z)

def relu_deriv(z):
    return np.where(z > 0, 1, 0)


class t_prior_VAE:

    def __init__(self, input_size, hidden_size1, hidden_size2, latent_size, df, random_seed=123):

        rng = np.random.RandomState(random_seed)
        self.df = df # degree of freedom of prior t-distribution

        # encoder weights
        self.W_e1 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size1, input_size))
        self.b_e1 = np.zeros((1, hidden_size1))

        self.W_e2 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size2, hidden_size1))
        self.b_e2 = np.zeros((1, hidden_size2))

        self.W_e3 = rng.normal(
            loc=0.0, scale=0.1, size=(latent_size * 2, hidden_size2))
        self.b_e3 = np.zeros((1, latent_size * 2))


        # decoder weights
        self.W_d1 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size2, latent_size))
        self.b_d1 = np.zeros((1, hidden_size2))

        self.W_d2 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size1, hidden_size2))
        self.b_d2 = np.zeros((1, hidden_size1))

        self.W_d3 = rng.normal(
            loc=0.0, scale=0.1, size=(input_size, hidden_size1))
        self.b_d3 = np.zeros((1, input_size))

    def encoder(self, x):
        z_e1 = x @ self.W_e1.T + self.b_e1
        a_e1 = relu(z_e1) # activation

        z_e2 = a_e1 @ self.W_e2.T + self.b_e2
        a_e2 = relu(z_e2) # activation

        mu_logvar = a_e2 @ self.W_e3.T + self.b_e3 # linear
        mu, logvar = np.split(mu_logvar, 2, axis=1)

        return z_e1, a_e1, z_e2, a_e2, mu, logvar

    def reparameterize(self, mu, logvar):
        std = np.exp(0.5 * logvar)
        eps = t.rvs(df=self.df, size=mu.shape) # student's t iid matrix with degree of freedom v+n

        latent = mu + eps * std

        return latent, eps

    def decoder(self, latent):
        z_d1 = latent @ self.W_d1.T + self.b_d1
        a_d1 = relu(z_d1) # activation

        z_d2 = a_d1 @ self.W_d2.T + self.b_d2
        a_d2 = relu(z_d2) # activation

        z_d3 = a_d2 @ self.W_d3.T + self.b_d3
        recon_x = sigmoid(z_d3) # sigmoid

        return z_d1, a_d1, z_d2, a_d2, recon_x

    def forward(self, x):
        z_e1, a_e1, z_e2, a_e2, mu, logvar = self.encoder(x)
        latent, eps = self.reparameterize(mu, logvar)
        z_d1, a_d1, z_d2, a_d2, recon_x = self.decoder(latent)

        return z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps

    def sample_latent(self, x):
        z_e1, a_e1, z_e2, a_e2, mu, logvar = self.encoder(x)
        latent, eps = self.reparameterize(mu, logvar)

        return latent, eps


    def backward(self, x, z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, y, eps):

        z_, eps_ = self.sample_latent(x) # Monte Calro sample from encoder

        # decoder backprop
        dL__dz_d3 = (recon_x - y) / y.shape[0] # only by REC

        dL__dw_d3 = dL__dz_d3.T @ a_d2
        dL__db_d3 = np.sum(dL__dz_d3, axis=0)


        dL__da_d2 = dL__dz_d3 @ self.W_d3
        dL__dz_d2 = dL__da_d2 * relu_deriv(z_d2) # activation derivative

        dL__dw_d2 = dL__dz_d2.T @ a_d1
        dL__db_d2 = np.sum(dL__dz_d2, axis=0)


        dL__da_d1 = dL__dz_d2 @ self.W_d2
        dL__dz_d1 = dL__da_d1 * relu_deriv(z_d1) # activation derivative

        dL__dw_d1 = dL__dz_d1.T @ latent
        dL__db_d1 = np.sum(dL__dz_d1, axis=0)


        # reparameterize backprop
        dL__dlatent = dL__dz_d1 @ self.W_d1

        dL__dmu = dL__dlatent * 1 # gradient by RCE term
        dL__dstd = dL__dlatent * eps # gradient by RCE term
        std = np.exp(0.5 * logvar)

        dL__dmu += ((self.df + 1) * z_ / (self.df + np.power(z_, 2)) * 1) / y.shape[0] # gradient by KL term
        dL__dstd += (-1 / std + (self.df + 1) * z_ / (self.df + np.power(z_, 2)) * eps_ ) / y.shape[0] # gradient by KL term

        dL__dlogvar = dL__dstd * 0.5 * std


        # encoder backprop
        dL__dz_e3 = np.hstack((dL__dmu, dL__dlogvar))

        dL__dw_e3 = dL__dz_e3.T @ a_e2
        dL__db_e3 = np.sum(dL__dz_e3, axis=0)


        dL__da_e2 = dL__dz_e3 @ self.W_e3
        dL__dz_e2 = dL__da_e2 * relu_deriv(z_e2) # activation derivative

        dL__dw_e2 = dL__dz_e2.T @ a_e1
        dL__db_e2 = np.sum(dL__dz_e2, axis=0)


        dL__da_e1 = dL__dz_e2 @ self.W_e2
        dL__dz_e1 = dL__da_e1 * relu_deriv(z_e1) # activation derivative

        dL__dw_e1 = dL__dz_e1.T @ x
        dL__db_e1 = np.sum(dL__dz_e1, axis=0)

        return dL__dw_d3, dL__db_d3, dL__dw_d2, dL__db_d2, dL__dw_d1, dL__db_d1, \
               dL__dw_e3, dL__db_e3, dL__dw_e2, dL__db_e2, dL__dw_e1, dL__db_e1

# %%
def minibatch_generator(X, y, minibatch_size): ##stable
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]

        yield X[batch_idx], y[batch_idx]

def sample_latent(nnet, x):
    z_e1, a_e1, z_e2, a_e2, mu, logvar = nnet.encoder(x)
    latent, eps = nnet.reparameterize(mu, logvar)

    return latent, eps

def compute_loss_mse(nnet, X, y, minibatch_size):
    loss_=0
    mse_=0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)

    for i, (X_mini, y_mini) in enumerate(minibatch_gen):

        z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps = nnet.forward(X_mini)

        z_, eps_ = sample_latent(nnet, X_mini)

        RCE = -np.sum(y_mini * np.log(recon_x) + (1 - y_mini) * np.log(1 - recon_x)) / minibatch_size # binary cross entropy loss
        KLD = np.sum(-0.5 * logvar + 0.5 * (nnet.df + 1) * (np.log(1 + 1 / nnet.df * np.power(z_, 2)) - np.log(1 + 1 / nnet.df * np.power(((z_ - mu) / np.exp(0.5 * logvar)), 2)))) / minibatch_size # KL divergence Loss

        loss = RCE + KLD
        loss_ += loss

        mse = np.mean((recon_x - y_mini) ** 2)
        mse_ += mse

    loss_ /= (i+1)
    mse_ /= (i+1)
    return loss_, mse_

def train(model, X_train, y_train, X_valid, y_valid, num_epochs, minibatch_size, learning_rate):

    epoch_train_loss = []
    epoch_valid_loss = []

    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:

            #### Compute outputs ####
            z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps = model.forward(X_train_mini)

            #### Compute gradients ####

            dL__dw_d3, dL__db_d3, dL__dw_d2, dL__db_d2, dL__dw_d1, dL__db_d1, dL__dw_e3, dL__db_e3, dL__dw_e2, dL__db_e2, dL__dw_e1, dL__db_e1 = \
                model.backward(X_train_mini, z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, y_train_mini, eps)

            #### Update weights ####
            model.W_d1 -= learning_rate * dL__dw_d1
            model.b_d1 -= learning_rate * dL__db_d1
            model.W_d2 -= learning_rate * dL__dw_d2
            model.b_d2 -= learning_rate * dL__db_d2
            model.W_d3 -= learning_rate * dL__dw_d3
            model.b_d3 -= learning_rate * dL__db_d3

            model.W_e1 -= learning_rate * dL__dw_e1
            model.b_e1 -= learning_rate * dL__db_e1
            model.W_e2 -= learning_rate * dL__dw_e2
            model.b_e2 -= learning_rate * dL__db_e2
            model.W_e3 -= learning_rate * dL__dw_e3
            model.b_e3 -= learning_rate * dL__db_e3

        #### Epoch Logging ####
        train_loss, train_mse = compute_loss_mse(model, X_train, y_train, minibatch_size)
        valid_loss, valid_mse = compute_loss_mse(model, X_valid, y_valid, minibatch_size)

        epoch_train_loss.append(train_loss)
        epoch_valid_loss.append(valid_loss)

        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train loss: {train_loss:.5f} '
              f'| Valid loss: {valid_loss:.5f} '
              f'| Train mse: {train_mse:.5f} '
              f'| Valid mse: {valid_mse:.5f} ')

    return epoch_train_loss, epoch_valid_loss

# %%
epochs=300
batch_size=500
lr=0.005
df=21

# %%
model=t_prior_VAE(28*28, 400, 128, 10, df=df)
epoch_train_loss, epoch_valid_loss = train(model, X_train, y_train, X_valid, y_valid, num_epochs=epochs, minibatch_size=batch_size, learning_rate=lr)
# Out:
# Epoch: 001/300 | Train loss: 203.13416 | Valid loss: 203.45827 | Train mse: 0.06275 | Valid mse: 0.06288
# Epoch: 002/300 | Train loss: 190.43368 | Valid loss: 190.47106 | Train mse: 0.05689 | Valid mse: 0.05686
# Epoch: 003/300 | Train loss: 180.90951 | Valid loss: 181.09310 | Train mse: 0.05202 | Valid mse: 0.05198
# Epoch: 004/300 | Train loss: 168.80226 | Valid loss: 169.08302 | Train mse: 0.04620 | Valid mse: 0.04619
# Epoch: 005/300 | Train loss: 161.67061 | Valid loss: 161.88319 | Train mse: 0.04286 | Valid mse: 0.04283
# Epoch: 006/300 | Train loss: 156.59888 | Valid loss: 156.71715 | Train mse: 0.04025 | Valid mse: 0.04017
# Epoch: 007/300 | Train loss: 154.82460 | Valid loss: 155.04804 | Train mse: 0.03918 | Valid mse: 0.03916
# Epoch: 008/300 | Train loss: 150.17625 | Valid loss: 150.31270 | Train mse: 0.03714 | Valid mse: 0.03709
# Epoch: 009/300 | Train loss: 149.33679 | Valid loss: 149.75693 | Train mse: 0.03726 | Valid mse: 0.03732
# Epoch: 010/300 | Train loss: 146.57470 | Valid loss: 146.84472 | Train mse: 0.03608 | Valid mse: 0.03608
# Epoch: 011/300 | Train loss: 143.04966 | Valid loss: 143.27167 | Train mse: 0.03437 | Valid mse: 0.03436
# Epoch: 012/300 | Train loss: 142.12937 | Valid loss: 142.46602 | Train mse: 0.03344 | Valid mse: 0.03347
# Epoch: 013/300 | Train loss: 144.42238 | Valid loss: 144.60969 | Train mse: 0.03428 | Valid mse: 0.03424
# Epoch: 014/300 | Train loss: 137.63081 | Valid loss: 137.80083 | Train mse: 0.03159 | Valid mse: 0.03160
# Epoch: 015/300 | Train loss: 136.33431 | Valid loss: 136.61419 | Train mse: 0.03098 | Valid mse: 0.03102
# Epoch: 016/300 | Train loss: 137.21309 | Valid loss: 137.63461 | Train mse: 0.03113 | Valid mse: 0.03120
# Epoch: 017/300 | Train loss: 134.01963 | Valid loss: 134.28550 | Train mse: 0.02955 | Valid mse: 0.02955
# Epoch: 018/300 | Train loss: 135.09859 | Valid loss: 135.39032 | Train mse: 0.03032 | Valid mse: 0.03036
# Epoch: 019/300 | Train loss: 133.51954 | Valid loss: 133.86725 | Train mse: 0.02955 | Valid mse: 0.02960
# Epoch: 020/300 | Train loss: 134.32325 | Valid loss: 134.63931 | Train mse: 0.02970 | Valid mse: 0.02977
# Epoch: 021/300 | Train loss: 131.37190 | Valid loss: 131.71207 | Train mse: 0.02881 | Valid mse: 0.02890
# Epoch: 022/300 | Train loss: 130.46996 | Valid loss: 130.96249 | Train mse: 0.02805 | Valid mse: 0.02814
# Epoch: 023/300 | Train loss: 129.21236 | Valid loss: 129.54545 | Train mse: 0.02753 | Valid mse: 0.02765
# Epoch: 024/300 | Train loss: 130.39789 | Valid loss: 130.87724 | Train mse: 0.02830 | Valid mse: 0.02840
# Epoch: 025/300 | Train loss: 134.04442 | Valid loss: 134.68839 | Train mse: 0.03010 | Valid mse: 0.03028
# Epoch: 026/300 | Train loss: 129.54572 | Valid loss: 130.13615 | Train mse: 0.02789 | Valid mse: 0.02805
# Epoch: 027/300 | Train loss: 127.78667 | Valid loss: 128.28836 | Train mse: 0.02681 | Valid mse: 0.02693
# Epoch: 028/300 | Train loss: 129.25603 | Valid loss: 129.67324 | Train mse: 0.02737 | Valid mse: 0.02749
# Epoch: 029/300 | Train loss: 127.49095 | Valid loss: 127.85187 | Train mse: 0.02677 | Valid mse: 0.02689
# Epoch: 030/300 | Train loss: 128.53819 | Valid loss: 129.11454 | Train mse: 0.02734 | Valid mse: 0.02750
# Epoch: 031/300 | Train loss: 128.97774 | Valid loss: 129.68817 | Train mse: 0.02756 | Valid mse: 0.02775
# Epoch: 032/300 | Train loss: 126.15111 | Valid loss: 126.58856 | Train mse: 0.02611 | Valid mse: 0.02621
# Epoch: 033/300 | Train loss: 127.23984 | Valid loss: 127.61169 | Train mse: 0.02638 | Valid mse: 0.02648
# Epoch: 034/300 | Train loss: 126.50474 | Valid loss: 127.11808 | Train mse: 0.02620 | Valid mse: 0.02640
# Epoch: 035/300 | Train loss: 126.38196 | Valid loss: 127.06631 | Train mse: 0.02647 | Valid mse: 0.02666
# Epoch: 036/300 | Train loss: 124.71821 | Valid loss: 125.26378 | Train mse: 0.02553 | Valid mse: 0.02569
# Epoch: 037/300 | Train loss: 125.33803 | Valid loss: 125.87165 | Train mse: 0.02569 | Valid mse: 0.02584
# Epoch: 038/300 | Train loss: 124.14860 | Valid loss: 124.86930 | Train mse: 0.02506 | Valid mse: 0.02530
# Epoch: 039/300 | Train loss: 125.68901 | Valid loss: 126.11920 | Train mse: 0.02582 | Valid mse: 0.02596
# Epoch: 040/300 | Train loss: 122.45422 | Valid loss: 123.07721 | Train mse: 0.02442 | Valid mse: 0.02460
# Epoch: 041/300 | Train loss: 124.54189 | Valid loss: 125.12102 | Train mse: 0.02552 | Valid mse: 0.02570
# Epoch: 042/300 | Train loss: 123.98598 | Valid loss: 124.58003 | Train mse: 0.02497 | Valid mse: 0.02515
# Epoch: 043/300 | Train loss: 123.16123 | Valid loss: 123.83799 | Train mse: 0.02480 | Valid mse: 0.02497
# Epoch: 044/300 | Train loss: 121.67384 | Valid loss: 122.52275 | Train mse: 0.02403 | Valid mse: 0.02428
# Epoch: 045/300 | Train loss: 122.00877 | Valid loss: 122.75053 | Train mse: 0.02427 | Valid mse: 0.02448
# Epoch: 046/300 | Train loss: 122.91673 | Valid loss: 123.66529 | Train mse: 0.02474 | Valid mse: 0.02499
# Epoch: 047/300 | Train loss: 123.38342 | Valid loss: 124.28400 | Train mse: 0.02498 | Valid mse: 0.02527
# Epoch: 048/300 | Train loss: 120.83896 | Valid loss: 121.53308 | Train mse: 0.02361 | Valid mse: 0.02380
# Epoch: 049/300 | Train loss: 121.73478 | Valid loss: 122.40776 | Train mse: 0.02409 | Valid mse: 0.02431
# Epoch: 050/300 | Train loss: 123.53112 | Valid loss: 124.10650 | Train mse: 0.02470 | Valid mse: 0.02486
# Epoch: 051/300 | Train loss: 120.31656 | Valid loss: 121.10908 | Train mse: 0.02342 | Valid mse: 0.02364
# Epoch: 052/300 | Train loss: 120.63688 | Valid loss: 121.44223 | Train mse: 0.02362 | Valid mse: 0.02386
# Epoch: 053/300 | Train loss: 121.47862 | Valid loss: 122.20166 | Train mse: 0.02387 | Valid mse: 0.02411
# Epoch: 054/300 | Train loss: 120.61390 | Valid loss: 121.33271 | Train mse: 0.02351 | Valid mse: 0.02375
# Epoch: 055/300 | Train loss: 121.34497 | Valid loss: 122.07734 | Train mse: 0.02385 | Valid mse: 0.02412
# Epoch: 056/300 | Train loss: 121.89993 | Valid loss: 122.73682 | Train mse: 0.02411 | Valid mse: 0.02438
# Epoch: 057/300 | Train loss: 120.08267 | Valid loss: 120.96823 | Train mse: 0.02339 | Valid mse: 0.02366
# Epoch: 058/300 | Train loss: 119.57405 | Valid loss: 120.41207 | Train mse: 0.02308 | Valid mse: 0.02336
# Epoch: 059/300 | Train loss: 120.58697 | Valid loss: 121.40204 | Train mse: 0.02362 | Valid mse: 0.02391
# Epoch: 060/300 | Train loss: 120.95581 | Valid loss: 121.58666 | Train mse: 0.02357 | Valid mse: 0.02376
# Epoch: 061/300 | Train loss: 122.07116 | Valid loss: 122.66146 | Train mse: 0.02422 | Valid mse: 0.02441
# Epoch: 062/300 | Train loss: 118.94201 | Valid loss: 119.72495 | Train mse: 0.02275 | Valid mse: 0.02302
# Epoch: 063/300 | Train loss: 118.53647 | Valid loss: 119.35826 | Train mse: 0.02247 | Valid mse: 0.02275
# Epoch: 064/300 | Train loss: 120.57965 | Valid loss: 121.55767 | Train mse: 0.02350 | Valid mse: 0.02379
# Epoch: 065/300 | Train loss: 119.61398 | Valid loss: 120.40914 | Train mse: 0.02302 | Valid mse: 0.02326
# Epoch: 066/300 | Train loss: 118.72884 | Valid loss: 119.61007 | Train mse: 0.02263 | Valid mse: 0.02294
# Epoch: 067/300 | Train loss: 118.04372 | Valid loss: 118.99193 | Train mse: 0.02229 | Valid mse: 0.02261
# Epoch: 068/300 | Train loss: 117.34560 | Valid loss: 118.23843 | Train mse: 0.02198 | Valid mse: 0.02228
# Epoch: 069/300 | Train loss: 118.27214 | Valid loss: 119.13458 | Train mse: 0.02251 | Valid mse: 0.02279
# Epoch: 070/300 | Train loss: 117.08518 | Valid loss: 118.06654 | Train mse: 0.02199 | Valid mse: 0.02231
# Epoch: 071/300 | Train loss: 119.61560 | Valid loss: 120.35401 | Train mse: 0.02302 | Valid mse: 0.02324
# Epoch: 072/300 | Train loss: 118.47865 | Valid loss: 119.57165 | Train mse: 0.02256 | Valid mse: 0.02292
# Epoch: 073/300 | Train loss: 117.23015 | Valid loss: 118.03724 | Train mse: 0.02191 | Valid mse: 0.02221
# Epoch: 074/300 | Train loss: 118.77873 | Valid loss: 119.86852 | Train mse: 0.02274 | Valid mse: 0.02308
# Epoch: 075/300 | Train loss: 116.36178 | Valid loss: 117.28803 | Train mse: 0.02158 | Valid mse: 0.02189
# Epoch: 076/300 | Train loss: 117.51322 | Valid loss: 118.42416 | Train mse: 0.02203 | Valid mse: 0.02233
# Epoch: 077/300 | Train loss: 117.43931 | Valid loss: 118.28594 | Train mse: 0.02208 | Valid mse: 0.02236
# Epoch: 078/300 | Train loss: 117.42666 | Valid loss: 118.27483 | Train mse: 0.02205 | Valid mse: 0.02235
# Epoch: 079/300 | Train loss: 117.59282 | Valid loss: 118.55147 | Train mse: 0.02217 | Valid mse: 0.02248
# Epoch: 080/300 | Train loss: 116.45488 | Valid loss: 117.33002 | Train mse: 0.02152 | Valid mse: 0.02185
# Epoch: 081/300 | Train loss: 117.42218 | Valid loss: 118.42198 | Train mse: 0.02208 | Valid mse: 0.02241
# Epoch: 082/300 | Train loss: 116.61407 | Valid loss: 117.63635 | Train mse: 0.02169 | Valid mse: 0.02205
# Epoch: 083/300 | Train loss: 116.37462 | Valid loss: 117.33391 | Train mse: 0.02151 | Valid mse: 0.02184
# Epoch: 084/300 | Train loss: 117.02677 | Valid loss: 118.00496 | Train mse: 0.02194 | Valid mse: 0.02230
# Epoch: 085/300 | Train loss: 115.91911 | Valid loss: 117.03770 | Train mse: 0.02145 | Valid mse: 0.02183
# Epoch: 086/300 | Train loss: 115.61921 | Valid loss: 116.72098 | Train mse: 0.02123 | Valid mse: 0.02158
# Epoch: 087/300 | Train loss: 115.52323 | Valid loss: 116.57358 | Train mse: 0.02109 | Valid mse: 0.02148
# Epoch: 088/300 | Train loss: 117.55312 | Valid loss: 118.45015 | Train mse: 0.02210 | Valid mse: 0.02242
# Epoch: 089/300 | Train loss: 116.11523 | Valid loss: 117.22664 | Train mse: 0.02154 | Valid mse: 0.02195
# Epoch: 090/300 | Train loss: 114.90178 | Valid loss: 115.95132 | Train mse: 0.02089 | Valid mse: 0.02130
# Epoch: 091/300 | Train loss: 115.90734 | Valid loss: 116.90043 | Train mse: 0.02141 | Valid mse: 0.02178
# Epoch: 092/300 | Train loss: 117.33827 | Valid loss: 118.36605 | Train mse: 0.02194 | Valid mse: 0.02229
# Epoch: 093/300 | Train loss: 116.08708 | Valid loss: 117.27297 | Train mse: 0.02146 | Valid mse: 0.02188
# Epoch: 094/300 | Train loss: 116.55100 | Valid loss: 117.67363 | Train mse: 0.02180 | Valid mse: 0.02222
# Epoch: 095/300 | Train loss: 115.12935 | Valid loss: 116.03027 | Train mse: 0.02096 | Valid mse: 0.02129
# Epoch: 096/300 | Train loss: 114.87606 | Valid loss: 115.97607 | Train mse: 0.02085 | Valid mse: 0.02123
# Epoch: 097/300 | Train loss: 117.22348 | Valid loss: 118.40759 | Train mse: 0.02191 | Valid mse: 0.02234
# Epoch: 098/300 | Train loss: 115.13067 | Valid loss: 116.31223 | Train mse: 0.02110 | Valid mse: 0.02153
# Epoch: 099/300 | Train loss: 114.88367 | Valid loss: 116.08956 | Train mse: 0.02089 | Valid mse: 0.02133
# Epoch: 100/300 | Train loss: 115.24995 | Valid loss: 116.43473 | Train mse: 0.02094 | Valid mse: 0.02133
# Epoch: 101/300 | Train loss: 115.04959 | Valid loss: 116.04830 | Train mse: 0.02092 | Valid mse: 0.02128
# Epoch: 102/300 | Train loss: 115.08666 | Valid loss: 116.17088 | Train mse: 0.02096 | Valid mse: 0.02137
# Epoch: 103/300 | Train loss: 114.18784 | Valid loss: 115.34521 | Train mse: 0.02054 | Valid mse: 0.02094
# Epoch: 104/300 | Train loss: 114.49901 | Valid loss: 115.62506 | Train mse: 0.02071 | Valid mse: 0.02110
# Epoch: 105/300 | Train loss: 113.59727 | Valid loss: 114.83191 | Train mse: 0.02032 | Valid mse: 0.02079
# Epoch: 106/300 | Train loss: 115.23443 | Valid loss: 116.48947 | Train mse: 0.02102 | Valid mse: 0.02149
# Epoch: 107/300 | Train loss: 113.59128 | Valid loss: 114.72643 | Train mse: 0.02022 | Valid mse: 0.02063
# Epoch: 108/300 | Train loss: 114.30144 | Valid loss: 115.40460 | Train mse: 0.02065 | Valid mse: 0.02105
# Epoch: 109/300 | Train loss: 113.75785 | Valid loss: 115.05180 | Train mse: 0.02042 | Valid mse: 0.02088
# Epoch: 110/300 | Train loss: 114.48515 | Valid loss: 115.53430 | Train mse: 0.02064 | Valid mse: 0.02104
# Epoch: 111/300 | Train loss: 113.96922 | Valid loss: 114.94048 | Train mse: 0.02041 | Valid mse: 0.02079
# Epoch: 112/300 | Train loss: 113.84266 | Valid loss: 114.98039 | Train mse: 0.02047 | Valid mse: 0.02091
# Epoch: 113/300 | Train loss: 113.40049 | Valid loss: 114.45387 | Train mse: 0.02016 | Valid mse: 0.02057
# Epoch: 114/300 | Train loss: 113.35796 | Valid loss: 114.60419 | Train mse: 0.02011 | Valid mse: 0.02058
# Epoch: 115/300 | Train loss: 115.57207 | Valid loss: 116.72212 | Train mse: 0.02112 | Valid mse: 0.02154
# Epoch: 116/300 | Train loss: 113.44386 | Valid loss: 114.66902 | Train mse: 0.02015 | Valid mse: 0.02059
# Epoch: 117/300 | Train loss: 113.02141 | Valid loss: 114.27207 | Train mse: 0.01999 | Valid mse: 0.02046
# Epoch: 118/300 | Train loss: 114.35096 | Valid loss: 115.68866 | Train mse: 0.02065 | Valid mse: 0.02114
# Epoch: 119/300 | Train loss: 114.68784 | Valid loss: 115.80835 | Train mse: 0.02082 | Valid mse: 0.02124
# Epoch: 120/300 | Train loss: 114.19095 | Valid loss: 115.49633 | Train mse: 0.02056 | Valid mse: 0.02104
# Epoch: 121/300 | Train loss: 115.26769 | Valid loss: 116.39445 | Train mse: 0.02098 | Valid mse: 0.02141
# Epoch: 122/300 | Train loss: 113.17104 | Valid loss: 114.56622 | Train mse: 0.02007 | Valid mse: 0.02058
# Epoch: 123/300 | Train loss: 112.68375 | Valid loss: 113.92108 | Train mse: 0.01984 | Valid mse: 0.02030
# Epoch: 124/300 | Train loss: 113.21285 | Valid loss: 114.56867 | Train mse: 0.02007 | Valid mse: 0.02057
# Epoch: 125/300 | Train loss: 113.32053 | Valid loss: 114.48191 | Train mse: 0.02018 | Valid mse: 0.02063
# Epoch: 126/300 | Train loss: 112.59656 | Valid loss: 114.00086 | Train mse: 0.01978 | Valid mse: 0.02029
# Epoch: 127/300 | Train loss: 114.07550 | Valid loss: 115.32722 | Train mse: 0.02051 | Valid mse: 0.02098
# Epoch: 128/300 | Train loss: 112.95427 | Valid loss: 114.35483 | Train mse: 0.01995 | Valid mse: 0.02045
# Epoch: 129/300 | Train loss: 112.46317 | Valid loss: 113.71675 | Train mse: 0.01979 | Valid mse: 0.02025
# Epoch: 130/300 | Train loss: 112.01625 | Valid loss: 113.25436 | Train mse: 0.01957 | Valid mse: 0.02001
# Epoch: 131/300 | Train loss: 113.54263 | Valid loss: 115.05040 | Train mse: 0.02021 | Valid mse: 0.02074
# Epoch: 132/300 | Train loss: 112.31557 | Valid loss: 113.58323 | Train mse: 0.01973 | Valid mse: 0.02020
# Epoch: 133/300 | Train loss: 114.13135 | Valid loss: 115.55221 | Train mse: 0.02051 | Valid mse: 0.02102
# Epoch: 134/300 | Train loss: 111.74234 | Valid loss: 113.00995 | Train mse: 0.01943 | Valid mse: 0.01991
# Epoch: 135/300 | Train loss: 113.17123 | Valid loss: 114.56831 | Train mse: 0.02010 | Valid mse: 0.02061
# Epoch: 136/300 | Train loss: 115.52485 | Valid loss: 116.56069 | Train mse: 0.02109 | Valid mse: 0.02150
# Epoch: 137/300 | Train loss: 112.25422 | Valid loss: 113.43006 | Train mse: 0.01959 | Valid mse: 0.02006
# Epoch: 138/300 | Train loss: 112.69918 | Valid loss: 114.10321 | Train mse: 0.01992 | Valid mse: 0.02044
# Epoch: 139/300 | Train loss: 112.07129 | Valid loss: 113.36550 | Train mse: 0.01957 | Valid mse: 0.02007
# Epoch: 140/300 | Train loss: 112.63761 | Valid loss: 113.88892 | Train mse: 0.01984 | Valid mse: 0.02033
# Epoch: 141/300 | Train loss: 112.11925 | Valid loss: 113.68497 | Train mse: 0.01964 | Valid mse: 0.02020
# Epoch: 142/300 | Train loss: 112.47029 | Valid loss: 113.89290 | Train mse: 0.01975 | Valid mse: 0.02029
# Epoch: 143/300 | Train loss: 111.65447 | Valid loss: 113.08501 | Train mse: 0.01940 | Valid mse: 0.01992
# Epoch: 144/300 | Train loss: 113.00648 | Valid loss: 114.29748 | Train mse: 0.01997 | Valid mse: 0.02044
# Epoch: 145/300 | Train loss: 112.35317 | Valid loss: 113.72380 | Train mse: 0.01972 | Valid mse: 0.02022
# Epoch: 146/300 | Train loss: 110.70461 | Valid loss: 112.10008 | Train mse: 0.01892 | Valid mse: 0.01945
# Epoch: 147/300 | Train loss: 112.04768 | Valid loss: 113.36278 | Train mse: 0.01952 | Valid mse: 0.01998
# Epoch: 148/300 | Train loss: 111.67829 | Valid loss: 112.94073 | Train mse: 0.01944 | Valid mse: 0.01995
# Epoch: 149/300 | Train loss: 112.33669 | Valid loss: 113.78888 | Train mse: 0.01965 | Valid mse: 0.02019
# Epoch: 150/300 | Train loss: 113.09128 | Valid loss: 114.24809 | Train mse: 0.01994 | Valid mse: 0.02038
# Epoch: 151/300 | Train loss: 112.54189 | Valid loss: 114.20117 | Train mse: 0.01981 | Valid mse: 0.02042
# Epoch: 152/300 | Train loss: 112.00779 | Valid loss: 113.35627 | Train mse: 0.01950 | Valid mse: 0.02003
# Epoch: 153/300 | Train loss: 113.69406 | Valid loss: 115.02116 | Train mse: 0.02029 | Valid mse: 0.02079
# Epoch: 154/300 | Train loss: 111.06934 | Valid loss: 112.52213 | Train mse: 0.01913 | Valid mse: 0.01967
# Epoch: 155/300 | Train loss: 111.35982 | Valid loss: 112.57965 | Train mse: 0.01924 | Valid mse: 0.01972
# Epoch: 156/300 | Train loss: 111.81512 | Valid loss: 113.24083 | Train mse: 0.01944 | Valid mse: 0.01994
# Epoch: 157/300 | Train loss: 111.68742 | Valid loss: 113.12726 | Train mse: 0.01938 | Valid mse: 0.01992
# Epoch: 158/300 | Train loss: 111.09019 | Valid loss: 112.64226 | Train mse: 0.01913 | Valid mse: 0.01969
# Epoch: 159/300 | Train loss: 111.46371 | Valid loss: 112.81328 | Train mse: 0.01928 | Valid mse: 0.01978
# Epoch: 160/300 | Train loss: 111.97821 | Valid loss: 113.45137 | Train mse: 0.01951 | Valid mse: 0.02008
# Epoch: 161/300 | Train loss: 111.00284 | Valid loss: 112.38042 | Train mse: 0.01907 | Valid mse: 0.01957
# Epoch: 162/300 | Train loss: 112.26213 | Valid loss: 113.92599 | Train mse: 0.01966 | Valid mse: 0.02029
# Epoch: 163/300 | Train loss: 111.28063 | Valid loss: 112.89581 | Train mse: 0.01921 | Valid mse: 0.01978
# Epoch: 164/300 | Train loss: 112.42254 | Valid loss: 113.86162 | Train mse: 0.01974 | Valid mse: 0.02025
# Epoch: 165/300 | Train loss: 111.74480 | Valid loss: 113.17391 | Train mse: 0.01938 | Valid mse: 0.01992
# Epoch: 166/300 | Train loss: 112.23016 | Valid loss: 113.77256 | Train mse: 0.01960 | Valid mse: 0.02018
# Epoch: 167/300 | Train loss: 111.57743 | Valid loss: 113.02191 | Train mse: 0.01935 | Valid mse: 0.01992
# Epoch: 168/300 | Train loss: 111.90676 | Valid loss: 113.39512 | Train mse: 0.01951 | Valid mse: 0.02008
# Epoch: 169/300 | Train loss: 111.34555 | Valid loss: 112.88295 | Train mse: 0.01928 | Valid mse: 0.01989
# Epoch: 170/300 | Train loss: 111.58953 | Valid loss: 113.13442 | Train mse: 0.01934 | Valid mse: 0.01992
# Epoch: 171/300 | Train loss: 110.54186 | Valid loss: 111.99591 | Train mse: 0.01894 | Valid mse: 0.01950
# Epoch: 172/300 | Train loss: 110.31888 | Valid loss: 111.89940 | Train mse: 0.01877 | Valid mse: 0.01935
# Epoch: 173/300 | Train loss: 110.63122 | Valid loss: 112.01406 | Train mse: 0.01886 | Valid mse: 0.01941
# Epoch: 174/300 | Train loss: 110.97539 | Valid loss: 112.64401 | Train mse: 0.01904 | Valid mse: 0.01963
# Epoch: 175/300 | Train loss: 110.84762 | Valid loss: 112.38899 | Train mse: 0.01900 | Valid mse: 0.01956
# Epoch: 176/300 | Train loss: 110.81226 | Valid loss: 112.37065 | Train mse: 0.01899 | Valid mse: 0.01958
# Epoch: 177/300 | Train loss: 110.80592 | Valid loss: 112.40380 | Train mse: 0.01899 | Valid mse: 0.01960
# Epoch: 178/300 | Train loss: 109.74374 | Valid loss: 111.41181 | Train mse: 0.01855 | Valid mse: 0.01919
# Epoch: 179/300 | Train loss: 110.77879 | Valid loss: 112.21898 | Train mse: 0.01898 | Valid mse: 0.01952
# Epoch: 180/300 | Train loss: 110.05593 | Valid loss: 111.62953 | Train mse: 0.01863 | Valid mse: 0.01920
# Epoch: 181/300 | Train loss: 109.98209 | Valid loss: 111.57498 | Train mse: 0.01858 | Valid mse: 0.01917
# Epoch: 182/300 | Train loss: 110.46780 | Valid loss: 112.22111 | Train mse: 0.01883 | Valid mse: 0.01947
# Epoch: 183/300 | Train loss: 109.43408 | Valid loss: 110.96150 | Train mse: 0.01840 | Valid mse: 0.01898
# Epoch: 184/300 | Train loss: 111.46663 | Valid loss: 112.92071 | Train mse: 0.01925 | Valid mse: 0.01984
# Epoch: 185/300 | Train loss: 109.89855 | Valid loss: 111.34083 | Train mse: 0.01859 | Valid mse: 0.01918
# Epoch: 186/300 | Train loss: 109.56364 | Valid loss: 111.33952 | Train mse: 0.01845 | Valid mse: 0.01912
# Epoch: 187/300 | Train loss: 110.31481 | Valid loss: 111.90374 | Train mse: 0.01877 | Valid mse: 0.01937
# Epoch: 188/300 | Train loss: 109.05226 | Valid loss: 110.73370 | Train mse: 0.01818 | Valid mse: 0.01882
# Epoch: 189/300 | Train loss: 110.56953 | Valid loss: 112.26511 | Train mse: 0.01885 | Valid mse: 0.01949
# Epoch: 190/300 | Train loss: 109.75281 | Valid loss: 111.25701 | Train mse: 0.01850 | Valid mse: 0.01908
# Epoch: 191/300 | Train loss: 109.74038 | Valid loss: 111.38018 | Train mse: 0.01850 | Valid mse: 0.01915
# Epoch: 192/300 | Train loss: 110.57554 | Valid loss: 112.23041 | Train mse: 0.01888 | Valid mse: 0.01949
# Epoch: 193/300 | Train loss: 110.08849 | Valid loss: 111.71853 | Train mse: 0.01869 | Valid mse: 0.01929
# Epoch: 194/300 | Train loss: 110.43703 | Valid loss: 112.18136 | Train mse: 0.01885 | Valid mse: 0.01952
# Epoch: 195/300 | Train loss: 109.96721 | Valid loss: 111.58917 | Train mse: 0.01863 | Valid mse: 0.01923
# Epoch: 196/300 | Train loss: 111.46231 | Valid loss: 113.07888 | Train mse: 0.01927 | Valid mse: 0.01987
# Epoch: 197/300 | Train loss: 109.78842 | Valid loss: 111.35931 | Train mse: 0.01850 | Valid mse: 0.01909
# Epoch: 198/300 | Train loss: 111.13268 | Valid loss: 112.81079 | Train mse: 0.01916 | Valid mse: 0.01981
# Epoch: 199/300 | Train loss: 110.18793 | Valid loss: 111.73044 | Train mse: 0.01870 | Valid mse: 0.01929
# Epoch: 200/300 | Train loss: 109.61363 | Valid loss: 111.32758 | Train mse: 0.01845 | Valid mse: 0.01910
# Epoch: 201/300 | Train loss: 109.49974 | Valid loss: 111.25698 | Train mse: 0.01842 | Valid mse: 0.01907
# Epoch: 202/300 | Train loss: 109.24441 | Valid loss: 110.85862 | Train mse: 0.01822 | Valid mse: 0.01882
# Epoch: 203/300 | Train loss: 109.41287 | Valid loss: 110.98323 | Train mse: 0.01830 | Valid mse: 0.01892
# Epoch: 204/300 | Train loss: 109.39988 | Valid loss: 111.15799 | Train mse: 0.01835 | Valid mse: 0.01901
# Epoch: 205/300 | Train loss: 109.91595 | Valid loss: 111.59716 | Train mse: 0.01854 | Valid mse: 0.01916
# Epoch: 206/300 | Train loss: 110.30034 | Valid loss: 111.98214 | Train mse: 0.01876 | Valid mse: 0.01938
# Epoch: 207/300 | Train loss: 109.35486 | Valid loss: 111.13749 | Train mse: 0.01833 | Valid mse: 0.01898
# Epoch: 208/300 | Train loss: 109.79280 | Valid loss: 111.59412 | Train mse: 0.01850 | Valid mse: 0.01917
# Epoch: 209/300 | Train loss: 109.96996 | Valid loss: 111.65444 | Train mse: 0.01862 | Valid mse: 0.01929
# Epoch: 210/300 | Train loss: 109.78075 | Valid loss: 111.47337 | Train mse: 0.01853 | Valid mse: 0.01918
# Epoch: 211/300 | Train loss: 109.37893 | Valid loss: 111.26061 | Train mse: 0.01828 | Valid mse: 0.01899
# Epoch: 212/300 | Train loss: 108.66689 | Valid loss: 110.49725 | Train mse: 0.01796 | Valid mse: 0.01867
# Epoch: 213/300 | Train loss: 111.18789 | Valid loss: 112.89792 | Train mse: 0.01910 | Valid mse: 0.01975
# Epoch: 214/300 | Train loss: 108.83032 | Valid loss: 110.56202 | Train mse: 0.01807 | Valid mse: 0.01873
# Epoch: 215/300 | Train loss: 109.33777 | Valid loss: 111.07823 | Train mse: 0.01834 | Valid mse: 0.01898
# Epoch: 216/300 | Train loss: 109.31040 | Valid loss: 110.98801 | Train mse: 0.01832 | Valid mse: 0.01897
# Epoch: 217/300 | Train loss: 108.65858 | Valid loss: 110.30944 | Train mse: 0.01801 | Valid mse: 0.01862
# Epoch: 218/300 | Train loss: 108.54633 | Valid loss: 110.32635 | Train mse: 0.01796 | Valid mse: 0.01865
# Epoch: 219/300 | Train loss: 110.37890 | Valid loss: 112.04817 | Train mse: 0.01879 | Valid mse: 0.01942
# Epoch: 220/300 | Train loss: 108.20291 | Valid loss: 109.91099 | Train mse: 0.01773 | Valid mse: 0.01840
# Epoch: 221/300 | Train loss: 108.38023 | Valid loss: 110.08394 | Train mse: 0.01786 | Valid mse: 0.01849
# Epoch: 222/300 | Train loss: 109.52290 | Valid loss: 111.18862 | Train mse: 0.01840 | Valid mse: 0.01907
# Epoch: 223/300 | Train loss: 108.74437 | Valid loss: 110.49055 | Train mse: 0.01805 | Valid mse: 0.01871
# Epoch: 224/300 | Train loss: 108.96407 | Valid loss: 110.66108 | Train mse: 0.01812 | Valid mse: 0.01877
# Epoch: 225/300 | Train loss: 110.06416 | Valid loss: 111.88778 | Train mse: 0.01860 | Valid mse: 0.01932
# Epoch: 226/300 | Train loss: 109.61470 | Valid loss: 111.42136 | Train mse: 0.01844 | Valid mse: 0.01915
# Epoch: 227/300 | Train loss: 110.01607 | Valid loss: 111.88884 | Train mse: 0.01863 | Valid mse: 0.01932
# Epoch: 228/300 | Train loss: 109.24092 | Valid loss: 110.91372 | Train mse: 0.01828 | Valid mse: 0.01890
# Epoch: 229/300 | Train loss: 109.78066 | Valid loss: 111.46969 | Train mse: 0.01846 | Valid mse: 0.01912
# Epoch: 230/300 | Train loss: 109.30344 | Valid loss: 111.05527 | Train mse: 0.01831 | Valid mse: 0.01900
# Epoch: 231/300 | Train loss: 108.91216 | Valid loss: 110.66361 | Train mse: 0.01814 | Valid mse: 0.01882
# Epoch: 232/300 | Train loss: 108.91122 | Valid loss: 110.76780 | Train mse: 0.01812 | Valid mse: 0.01883
# Epoch: 233/300 | Train loss: 109.60474 | Valid loss: 111.34804 | Train mse: 0.01837 | Valid mse: 0.01903
# Epoch: 234/300 | Train loss: 108.07826 | Valid loss: 109.97158 | Train mse: 0.01779 | Valid mse: 0.01851
# Epoch: 235/300 | Train loss: 110.40922 | Valid loss: 112.08131 | Train mse: 0.01873 | Valid mse: 0.01936
# Epoch: 236/300 | Train loss: 108.75114 | Valid loss: 110.46278 | Train mse: 0.01801 | Valid mse: 0.01865
# Epoch: 237/300 | Train loss: 107.81546 | Valid loss: 109.74463 | Train mse: 0.01757 | Valid mse: 0.01828
# Epoch: 238/300 | Train loss: 108.89329 | Valid loss: 110.67814 | Train mse: 0.01805 | Valid mse: 0.01875
# Epoch: 239/300 | Train loss: 108.09403 | Valid loss: 109.97805 | Train mse: 0.01772 | Valid mse: 0.01842
# Epoch: 240/300 | Train loss: 108.68512 | Valid loss: 110.58988 | Train mse: 0.01803 | Valid mse: 0.01878
# Epoch: 241/300 | Train loss: 109.06854 | Valid loss: 111.09604 | Train mse: 0.01819 | Valid mse: 0.01896
# Epoch: 242/300 | Train loss: 108.37188 | Valid loss: 110.22223 | Train mse: 0.01786 | Valid mse: 0.01855
# Epoch: 243/300 | Train loss: 108.04159 | Valid loss: 109.81540 | Train mse: 0.01771 | Valid mse: 0.01839
# Epoch: 244/300 | Train loss: 108.28732 | Valid loss: 110.31060 | Train mse: 0.01778 | Valid mse: 0.01852
# Epoch: 245/300 | Train loss: 108.21696 | Valid loss: 110.03026 | Train mse: 0.01773 | Valid mse: 0.01845
# Epoch: 246/300 | Train loss: 109.17573 | Valid loss: 111.05941 | Train mse: 0.01820 | Valid mse: 0.01890
# Epoch: 247/300 | Train loss: 108.88423 | Valid loss: 110.75462 | Train mse: 0.01804 | Valid mse: 0.01874
# Epoch: 248/300 | Train loss: 108.47551 | Valid loss: 110.37161 | Train mse: 0.01789 | Valid mse: 0.01863
# Epoch: 249/300 | Train loss: 108.45514 | Valid loss: 110.30905 | Train mse: 0.01787 | Valid mse: 0.01860
# Epoch: 250/300 | Train loss: 107.97587 | Valid loss: 109.88476 | Train mse: 0.01768 | Valid mse: 0.01842
# Epoch: 251/300 | Train loss: 107.99723 | Valid loss: 109.84479 | Train mse: 0.01769 | Valid mse: 0.01841
# Epoch: 252/300 | Train loss: 109.01540 | Valid loss: 110.77553 | Train mse: 0.01820 | Valid mse: 0.01890
# Epoch: 253/300 | Train loss: 108.28286 | Valid loss: 110.18843 | Train mse: 0.01778 | Valid mse: 0.01847
# Epoch: 254/300 | Train loss: 107.62492 | Valid loss: 109.54383 | Train mse: 0.01748 | Valid mse: 0.01822
# Epoch: 255/300 | Train loss: 108.98183 | Valid loss: 110.86296 | Train mse: 0.01812 | Valid mse: 0.01882
# Epoch: 256/300 | Train loss: 108.48112 | Valid loss: 110.34642 | Train mse: 0.01790 | Valid mse: 0.01864
# Epoch: 257/300 | Train loss: 108.02470 | Valid loss: 110.00077 | Train mse: 0.01771 | Valid mse: 0.01849
# Epoch: 258/300 | Train loss: 107.90583 | Valid loss: 109.80421 | Train mse: 0.01765 | Valid mse: 0.01840
# Epoch: 259/300 | Train loss: 108.60188 | Valid loss: 110.46428 | Train mse: 0.01795 | Valid mse: 0.01867
# Epoch: 260/300 | Train loss: 107.77305 | Valid loss: 109.70154 | Train mse: 0.01757 | Valid mse: 0.01828
# Epoch: 261/300 | Train loss: 108.02169 | Valid loss: 110.12748 | Train mse: 0.01766 | Valid mse: 0.01846
# Epoch: 262/300 | Train loss: 107.69202 | Valid loss: 109.60269 | Train mse: 0.01751 | Valid mse: 0.01825
# Epoch: 263/300 | Train loss: 107.71929 | Valid loss: 109.55148 | Train mse: 0.01755 | Valid mse: 0.01827
# Epoch: 264/300 | Train loss: 108.49223 | Valid loss: 110.34125 | Train mse: 0.01791 | Valid mse: 0.01863
# Epoch: 265/300 | Train loss: 108.76115 | Valid loss: 110.68116 | Train mse: 0.01801 | Valid mse: 0.01875
# Epoch: 266/300 | Train loss: 107.24187 | Valid loss: 109.32145 | Train mse: 0.01733 | Valid mse: 0.01810
# Epoch: 267/300 | Train loss: 108.09205 | Valid loss: 109.99900 | Train mse: 0.01772 | Valid mse: 0.01843
# Epoch: 268/300 | Train loss: 107.34067 | Valid loss: 109.25319 | Train mse: 0.01735 | Valid mse: 0.01808
# Epoch: 269/300 | Train loss: 107.88410 | Valid loss: 109.90670 | Train mse: 0.01757 | Valid mse: 0.01833
# Epoch: 270/300 | Train loss: 106.74028 | Valid loss: 108.69645 | Train mse: 0.01709 | Valid mse: 0.01786
# Epoch: 271/300 | Train loss: 109.48528 | Valid loss: 111.60395 | Train mse: 0.01835 | Valid mse: 0.01912
# Epoch: 272/300 | Train loss: 107.58980 | Valid loss: 109.51701 | Train mse: 0.01753 | Valid mse: 0.01827
# Epoch: 273/300 | Train loss: 107.74402 | Valid loss: 109.72748 | Train mse: 0.01754 | Valid mse: 0.01827
# Epoch: 274/300 | Train loss: 107.37464 | Valid loss: 109.47418 | Train mse: 0.01733 | Valid mse: 0.01815
# Epoch: 275/300 | Train loss: 107.27085 | Valid loss: 109.26619 | Train mse: 0.01732 | Valid mse: 0.01810
# Epoch: 276/300 | Train loss: 108.40811 | Valid loss: 110.57533 | Train mse: 0.01786 | Valid mse: 0.01868
# Epoch: 277/300 | Train loss: 107.66290 | Valid loss: 109.70325 | Train mse: 0.01753 | Valid mse: 0.01832
# Epoch: 278/300 | Train loss: 107.60522 | Valid loss: 109.43429 | Train mse: 0.01750 | Valid mse: 0.01821
# Epoch: 279/300 | Train loss: 106.98767 | Valid loss: 108.99552 | Train mse: 0.01722 | Valid mse: 0.01798
# Epoch: 280/300 | Train loss: 106.86149 | Valid loss: 108.88104 | Train mse: 0.01709 | Valid mse: 0.01789
# Epoch: 281/300 | Train loss: 107.72695 | Valid loss: 109.71544 | Train mse: 0.01756 | Valid mse: 0.01834
# Epoch: 282/300 | Train loss: 109.05649 | Valid loss: 111.07476 | Train mse: 0.01811 | Valid mse: 0.01885
# Epoch: 283/300 | Train loss: 107.85531 | Valid loss: 109.92443 | Train mse: 0.01765 | Valid mse: 0.01846
# Epoch: 284/300 | Train loss: 107.65408 | Valid loss: 109.73864 | Train mse: 0.01755 | Valid mse: 0.01835
# Epoch: 285/300 | Train loss: 107.21224 | Valid loss: 109.11898 | Train mse: 0.01731 | Valid mse: 0.01808
# Epoch: 286/300 | Train loss: 108.64413 | Valid loss: 110.72339 | Train mse: 0.01794 | Valid mse: 0.01872
# Epoch: 287/300 | Train loss: 107.17488 | Valid loss: 109.12150 | Train mse: 0.01730 | Valid mse: 0.01805
# Epoch: 288/300 | Train loss: 109.28395 | Valid loss: 111.34643 | Train mse: 0.01828 | Valid mse: 0.01911
# Epoch: 289/300 | Train loss: 107.70307 | Valid loss: 109.81389 | Train mse: 0.01753 | Valid mse: 0.01834
# Epoch: 290/300 | Train loss: 106.68863 | Valid loss: 108.78582 | Train mse: 0.01703 | Valid mse: 0.01785
# Epoch: 291/300 | Train loss: 106.81376 | Valid loss: 108.77234 | Train mse: 0.01711 | Valid mse: 0.01785
# Epoch: 292/300 | Train loss: 107.57567 | Valid loss: 109.48448 | Train mse: 0.01740 | Valid mse: 0.01815
# Epoch: 293/300 | Train loss: 106.30701 | Valid loss: 108.35935 | Train mse: 0.01691 | Valid mse: 0.01772
# Epoch: 294/300 | Train loss: 107.84261 | Valid loss: 109.93667 | Train mse: 0.01759 | Valid mse: 0.01838
# Epoch: 295/300 | Train loss: 108.34950 | Valid loss: 110.36564 | Train mse: 0.01781 | Valid mse: 0.01860
# Epoch: 296/300 | Train loss: 106.93696 | Valid loss: 109.00782 | Train mse: 0.01718 | Valid mse: 0.01798
# Epoch: 297/300 | Train loss: 108.17456 | Valid loss: 110.18243 | Train mse: 0.01779 | Valid mse: 0.01856
# Epoch: 298/300 | Train loss: 107.06573 | Valid loss: 109.09303 | Train mse: 0.01721 | Valid mse: 0.01796
# Epoch: 299/300 | Train loss: 106.62541 | Valid loss: 108.73959 | Train mse: 0.01702 | Valid mse: 0.01782
# Epoch: 300/300 | Train loss: 107.41460 | Valid loss: 109.45569 | Train mse: 0.01743 | Valid mse: 0.01822

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(epoch_train_loss)), epoch_train_loss,
         label='Training')
plt.plot(range(len(epoch_valid_loss)), epoch_valid_loss,
         label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
import pickle

with open('t_prior_VAE_MNIST.p', 'wb') as file:
    pickle.dump(model, file)
    pickle.dump(epoch_train_loss, file)
    pickle.dump(epoch_valid_loss, file)

# %%
n=np.random.randint(0,10000,1)
n=3001
plt.figure(figsize=(2, 2)) # original data
plt.imshow(X_test[n,:].reshape(28,28),cmap='Greys')
plt.axis('off')
plt.show()

fig, ax = plt.subplots(nrows=3, ncols=10, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(30):
    _, _, _, _, _, _, _, _, _, _, _, pred, _ = model.forward(X_test[n,:])
    img = pred.reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()
